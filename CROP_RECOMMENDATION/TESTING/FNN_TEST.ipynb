# %%
import pandas as pd
import numpy as np
import joblib

# %%
scaler=joblib.load(r"C:\Users\Avijit\Desktop\AgriAssure\CROP_RECOMMENDATION\ENCODER-DECODER\scalerx.pkl")

# %%
model=joblib.load(r"C:\Users\Avijit\Desktop\AgriAssure\CROP_RECOMMENDATION\MODELS\fnn.pkl")

# %%
decoder=joblib.load(r"C:\Users\Avijit\Desktop\AgriAssure\CROP_RECOMMENDATION\ENCODER-DECODER\label_en.pkl")

# %%
data=pd.read_csv(r"C:\Users\Avijit\Desktop\AgriAssure\CROP_RECOMMENDATION\DATASET\Crop_recommendation.csv")
data.iloc[230:470]
# Out:
#       N   P   K  temperature   humidity        ph    rainfall       label
# 230  28  76  82    20.566019  14.258040  6.654425   83.759371    chickpea
# 231  42  79  85    17.223852  15.820693  6.129534   76.575810    chickpea
# 232  32  60  83    19.691417  19.442254  8.829273   91.760716    chickpea
# 233  22  78  76    17.848517  19.091729  8.621663   76.324707    chickpea
# 234  31  79  75    18.820225  16.107479  8.204862   89.731194    chickpea
# ..   ..  ..  ..          ...        ...       ...         ...         ...
# 465   7  77  18    20.559126  60.548807  6.655918  191.089511  pigeonpeas
# 466  29  78  25    19.959917  59.331578  5.982855  195.787103  pigeonpeas
# 467  30  60  21    28.876676  62.490121  5.457871  182.268818  pigeonpeas
# 468  20  74  16    36.043537  43.614441  4.759490  159.893865  pigeonpeas
# 469  19  57  23    23.673433  47.287969  7.342410  141.125072  pigeonpeas
#
# [240 rows x 8 columns]

# %%
input=np.array([[20	,74	,16	,36.043537	,43.614441	,4.759490,159.893865]])

# %%
input=scaler.transform(input)
# Out:
# c:\Users\Avijit\anaconda3\envs\DL\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
output=np.argmax(model.predict(input),axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step

# %%
prediciton=decoder.inverse_transform(output)[0]

# %%
print(f"prediciton: {prediciton}")
# Out:
# prediciton: pigeonpeas
