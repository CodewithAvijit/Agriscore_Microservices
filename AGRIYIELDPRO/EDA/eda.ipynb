# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_selection import SelectKBest
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\Avijit\Desktop\AgriAssure\AGRIYIELDPRO\DATASET\crop_yield-03.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19689 entries, 0 to 19688
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Crop             19689 non-null  object
#  1   Crop_Year        19689 non-null  int64
#  2   Season           19689 non-null  object
#  3   State            19689 non-null  object
#  4   Area             19689 non-null  float64
#  5   Production       19689 non-null  int64
#  6   Annual_Rainfall  19689 non-null  float64
#  7   Fertilizer       19689 non-null  float64
#  8   Pesticide        19689 non-null  float64
#  9   Yield            19689 non-null  float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 1.5+ MB

# %%
data.describe()
# Out:
#           Crop_Year          Area    Production  Annual_Rainfall  \
# count  19689.000000  1.968900e+04  1.968900e+04     19689.000000
# mean    2009.127584  1.799266e+05  1.643594e+07      1437.755177
# std        6.498099  7.328287e+05  2.630568e+08       816.909589
# min     1997.000000  5.000000e-01  0.000000e+00       301.300000
# 25%     2004.000000  1.390000e+03  1.393000e+03       940.700000
# 50%     2010.000000  9.317000e+03  1.380400e+04      1247.600000
# 75%     2015.000000  7.511200e+04  1.227180e+05      1643.700000
# max     2020.000000  5.080810e+07  6.326000e+09      6552.700000
#
#          Fertilizer     Pesticide         Yield
# count  1.968900e+04  1.968900e+04  19689.000000
# mean   2.410331e+07  4.884835e+04     79.954009
# std    9.494600e+07  2.132874e+05    878.306193
# min    5.417000e+01  9.000000e-02      0.000000
# 25%    1.880146e+05  3.567000e+02      0.600000
# 50%    1.234957e+06  2.421900e+03      1.030000
# 75%    1.000385e+07  2.004170e+04      2.388889
# max    4.835407e+09  1.575051e+07  21105.000000

# %%
data.head()
# Out:
#            Crop  Crop_Year       Season  State     Area  Production  \
# 0      Arecanut       1997  Whole Year   Assam  73814.0       56708
# 1     Arhar/Tur       1997  Kharif       Assam   6637.0        4685
# 2   Castor seed       1997  Kharif       Assam    796.0          22
# 3      Coconut        1997  Whole Year   Assam  19656.0   126905000
# 4  Cotton(lint)       1997  Kharif       Assam   1739.0         794
#
#    Annual_Rainfall  Fertilizer  Pesticide        Yield
# 0           2051.4  7024878.38   22882.34     0.796087
# 1           2051.4   631643.29    2057.47     0.710435
# 2           2051.4    75755.32     246.76     0.238333
# 3           2051.4  1870661.52    6093.36  5238.051739
# 4           2051.4   165500.63     539.09     0.420909

# %%
data.shape
# Out:
# (19689, 10)

# %%
sns.heatmap(data.isnull(), cmap="viridis")
plt.title("Missing Values Heatmap")
plt.show()

# %%
data.isnull().sum()
# Out:
# Crop               0
# Crop_Year          0
# Season             0
# State              0
# Area               0
# Production         0
# Annual_Rainfall    0
# Fertilizer         0
# Pesticide          0
# Yield              0
# dtype: int64

# %%
print("\n🔹 Unique values in each column:")
for col in data.columns:
    print(f"{col}: {data[col].nunique()}")
# Out:
# 🔹 Unique values in each column:
# Crop: 55
# Crop_Year: 24
# Season: 6
# State: 30
# Area: 13644
# Production: 14016
# Annual_Rainfall: 634
# Fertilizer: 18598
# Pesticide: 17405
# Yield: 13551

# %%
categorical = data.select_dtypes(include='object').columns.tolist()
print("\n🔹 Category value counts:")
for col in categorical:
    print(f"\n{col}:\n{data[col].value_counts()}")
# Out:
# 🔹 Category value counts:
#
# Crop:
# Crop
# Rice                     1197
# Maize                     975
# Moong(Green Gram)         740
# Urad                      733
# Groundnut                 725
# Sesamum                   685
# Potato                    628
# Sugarcane                 605
# Wheat                     545
# Rapeseed &Mustard         528
# Bajra                     524
# Jowar                     513
# Arhar/Tur                 508
# Ragi                      498
# Gram                      490
# Small millets             485
# Cotton(lint)              476
# Onion                     454
# Sunflower                 441
# Dry chillies              419
# Other Kharif pulses       382
# Horse-gram                371
# Peas & beans (Pulses)     369
# Tobacco                   364
# Other  Rabi pulses        355
# Soyabean                  349
# Turmeric                  337
# Masoor                    324
# Ginger                    323
# Linseed                   308
# Castor seed               300
# Barley                    297
# Sweet potato              273
# Garlic                    250
# Banana                    245
# Mesta                     210
# Tapioca                   201
# Coriander                 199
# Niger seed                192
# Jute                      181
# Coconut                   172
# Safflower                 169
# Arecanut                  162
# Sannhamp                  160
# Other Cereals             146
# Cashewnut                 134
# Cowpea(Lobia)             134
# other oilseeds            126
# Black pepper              126
# Moth                      110
# Khesari                    75
# Cardamom                   74
# Guar seed                  63
# Oilseeds total             29
# Other Summer Pulses        10
# Name: count, dtype: int64
#
# Season:
# Season
# Kharif         8232
# Rabi           5742
# Whole Year     3717
# Summer         1195
# Autumn          414
# Winter          389
# Name: count, dtype: int64
#
# State:
# State
# Karnataka            1432
# Andhra Pradesh       1266
# West Bengal          1094
# Chhattisgarh          915
# Bihar                 896
# Madhya Pradesh        845
# Uttar Pradesh         825
# Tamil Nadu            822
# Gujarat               817
# Maharashtra           770
# Uttarakhand           764
# Odisha                760
# Assam                 731
# Nagaland              689
# Puducherry            670
# Meghalaya             649
# Jammu and Kashmir     631
# Haryana               631
# Himachal Pradesh      616
# Kerala                534
# Manipur               444
# Tripura               441
# Mizoram               416
# Punjab                397
# Telangana             397
# Arunachal Pradesh     292
# Jharkhand             270
# Goa                   246
# Sikkim                226
# Delhi                 203
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(data.corr(numeric_only=True), annot=True, cmap='viridis', fmt=".2f")
plt.title("🔹 Correlation Heatmap")
plt.xticks(rotation=45)
plt.show()
# Out:
# c:\Users\Avijit\Desktop\AgriAssure\AGROENV\lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128313 (\N{SMALL BLUE DIAMOND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=data)
plt.title("Boxplot of All Numeric Columns")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
for col in num_cols:
    plt.figure(figsize=(6, 3))
    sns.histplot(data[col], kde=True)
    plt.title(f"Distribution - {col}")
    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 3
#       1 for col in num_cols:
#       2     plt.figure(figsize=(6, 3))
# ----> 3     sns.histplot(data[col], kde=True)
#       4     plt.title(f"Distribution - {col}")
#       5     plt.tight_layout()
#
# File c:\Users\Avijit\Desktop\AgriAssure\AGROENV\lib\site-packages\seaborn\distributions.py:1416, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1405 estimate_kws = dict(
#    1406     stat=stat,
#    1407     bins=bins,
#    (...)
#    1411     cumulative=cumulative,
#    1412 )
#    1414 if p.univariate:
# -> 1416     p.plot_univariate_histogram(
#    1417         multiple=multiple,
#    1418         element=element,
#    1419         fill=fill,
#    1420         shrink=shrink,
#    1421         common_norm=common_norm,
#    1422         common_bins=common_bins,
#    1423         kde=kde,
#    1424         kde_kws=kde_kws,
#    1425         color=color,
#    1426         legend=legend,
#    1427         estimate_kws=estimate_kws,
#    1428         line_kws=line_kws,
#    1429         **kwargs,
#    1430     )
#    1432 else:
#    1434     p.plot_bivariate_histogram(
#    1435         common_bins=common_bins,
#    1436         common_norm=common_norm,
#    (...)
#    1446         **kwargs,
#    1447     )
#
# File c:\Users\Avijit\Desktop\AgriAssure\AGROENV\lib\site-packages\seaborn\distributions.py:571, in _DistributionPlotter.plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     566 if element == "bars":
#     567
#     568     # Use matplotlib bar plotting
#     570     plot_func = ax.bar if self.data_variable == "x" else ax.barh
# --> 571     artists = plot_func(
#     572         hist["edges"],
#     573         hist["heights"] - bottom,
#     574         hist["widths"],
#     575         bottom,
#     576         align="edge",
#     577         **artist_kws,
#     578     )
#     580     for bar in artists:
#     581         if self.data_variable == "x":
#
# File c:\Users\Avijit\Desktop\AgriAssure\AGROENV\lib\site-packages\matplotlib\__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File c:\Users\Avijit\Desktop\AgriAssure\AGROENV\lib\site-packages\matplotlib\axes\_axes.py:2660, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2658     else:  # horizontal
#    2659         r.sticky_edges.x.append(l)
# -> 2660     self.add_patch(r)
#    2661     patches.append(r)
#    2663 if xerr is not None or yerr is not None:
#
# File c:\Users\Avijit\Desktop\AgriAssure\AGROENV\lib\site-packages\matplotlib\axes\_base.py:2482, in _AxesBase.add_patch(self, p)
#    2480 if p.get_clip_path() is None:
#    2481     p.set_clip_path(self.patch)
# -> 2482 self._update_patch_limits(p)
#    2483 self._children.append(p)
#    2484 p._remove_method = self._children.remove
#
# File c:\Users\Avijit\Desktop\AgriAssure\AGROENV\lib\site-packages\matplotlib\axes\_base.py:2524, in _AxesBase._update_patch_limits(self, patch)
#    2522         updatey = False
#    2523 trf_to_data = patch_trf - self.transData
# -> 2524 xys = trf_to_data.transform(vertices)
#    2525 self.update_datalim(xys, updatex=updatex, updatey=updatey)
#
# File c:\Users\Avijit\Desktop\AgriAssure\AGROENV\lib\site-packages\matplotlib\transforms.py:1495, in Transform.transform(self, values)
#    1492 values = values.reshape((-1, self.input_dims))
#    1494 # Transform the values
# -> 1495 res = self.transform_affine(self.transform_non_affine(values))
#    1497 # Convert the result back to the shape of the input values.
#    1498 if ndim == 0:
#
# File c:\Users\Avijit\Desktop\AgriAssure\AGROENV\lib\site-packages\matplotlib\transforms.py:2410, in CompositeGenericTransform.transform_affine(self, values)
#    2408 def transform_affine(self, values):
#    2409     # docstring inherited
# -> 2410     return self.get_affine().transform(values)
#
# File c:\Users\Avijit\Desktop\AgriAssure\AGROENV\lib\site-packages\matplotlib\transforms.py:2436, in CompositeGenericTransform.get_affine(self)
#    2434     return self._b.get_affine()
#    2435 else:
# -> 2436     return Affine2D(np.dot(self._b.get_affine().get_matrix(),
#    2437                            self._a.get_affine().get_matrix()))
#
# KeyboardInterrupt:

# %%
sns.scatterplot(x='Production', y='Yield', data=data)
plt.title("Yield vs Production")
plt.show()

sns.scatterplot(x='Fertilizer', y='Yield', data=data)
plt.title("Yield vs Fertilizer")
plt.show()
