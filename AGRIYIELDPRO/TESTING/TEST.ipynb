# %%
import pandas as pd
import numpy as np
import joblib

# %%
scaler = joblib.load(r"C:\Users\Avijit\Desktop\AgriAssure\AGRIYIELDPRO\ENCODER-DECODER\scaler.pkl")
cropen = joblib.load(r"C:\Users\Avijit\Desktop\AgriAssure\AGRIYIELDPRO\ENCODER-DECODER\crop.pkl")
seasonen = joblib.load(r"C:\Users\Avijit\Desktop\AgriAssure\AGRIYIELDPRO\ENCODER-DECODER\season.pkl")
stateen = joblib.load(r"C:\Users\Avijit\Desktop\AgriAssure\AGRIYIELDPRO\ENCODER-DECODER\state.pkl")
model = joblib.load(r"C:\Users\Avijit\Desktop\AgriAssure\AGRIYIELDPRO\MODEL\histgradboosting.pkl")

# %%
crop = "Onion"
season = "Whole Year"
state = "Assam"
Area = 10729
Production = 7416
Annual_Rainfall = 2354.4
Fertilizer = 1060025.2
Pesticide = 3111.41

# %%
crop=cropen.transform([crop])[0]

# %%
stateen.classes_
# Out:
# array(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chhattisgarh', 'Delhi', 'Goa', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jammu and Kashmir', 'Jharkhand', 'Karnataka',
#        'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya',
#        'Mizoram', 'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Sikkim',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal'], dtype=object)
