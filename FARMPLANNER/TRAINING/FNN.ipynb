# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split,validation_curve
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix,f1_score
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow
import joblib

# %%
data=pd.read_csv(r"C:\Users\Avijit\Desktop\AgriAssure\CROP_RECOMMENDATION\PROCESS_DATASET\crop_recommendation_processed.csv")

# %%
x,y=data.iloc[:,:-1],data.iloc[:,-1:]

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.8,random_state=42)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Input,PReLU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2

# %%
len(np.unique(ytrain))
# Out:
# 22

# %%
model=Sequential([
    Input(shape=(7,)),
    Dense(units=64,kernel_regularizer=l2(0.1)),
    PReLU(),
    Dense(units=22,activation='softmax')
])

# %%
model.compile(optimizer=Adam(learning_rate=0.001),loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
stop=EarlyStopping(
    monitor='val_loss',
    verbose=1,
    min_delta=0.00001,
    restore_best_weights=True,
    patience=10
)

# %%
model_history=model.fit(xtrain,ytrain,epochs=100,batch_size=30,validation_data=(xtest,ytest),callbacks=stop)
# Out:
# Epoch 1/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2014 - loss: 4.0450 - val_accuracy: 0.3977 - val_loss: 3.3820
# Epoch 2/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4529 - loss: 3.2036 - val_accuracy: 0.5477 - val_loss: 2.7998
# Epoch 3/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5715 - loss: 2.6590 - val_accuracy: 0.6341 - val_loss: 2.3901
# Epoch 4/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6979 - loss: 2.2860 - val_accuracy: 0.6977 - val_loss: 2.0958
# Epoch 5/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7643 - loss: 2.0149 - val_accuracy: 0.7659 - val_loss: 1.8802
# Epoch 6/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8199 - loss: 1.8111 - val_accuracy: 0.7955 - val_loss: 1.7199
# Epoch 7/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8322 - loss: 1.6504 - val_accuracy: 0.8341 - val_loss: 1.6036
# Epoch 8/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8787 - loss: 1.5369 - val_accuracy: 0.8227 - val_loss: 1.5032
# Epoch 9/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8702 - loss: 1.4364 - val_accuracy: 0.8568 - val_loss: 1.4262
# Epoch 10/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8770 - loss: 1.3726 - val_accuracy: 0.8432 - val_loss: 1.3664
# Epoch 11/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8806 - loss: 1.3074 - val_accuracy: 0.8705 - val_loss: 1.3051
# Epoch 12/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9242 - loss: 1.2405 - val_accuracy: 0.8682 - val_loss: 1.2544
# Epoch 13/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9035 - loss: 1.1978 - val_accuracy: 0.8909 - val_loss: 1.2121
# Epoch 14/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9202 - loss: 1.1610 - val_accuracy: 0.8886 - val_loss: 1.1788
# Epoch 15/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9267 - loss: 1.1107 - val_accuracy: 0.9023 - val_loss: 1.1409
# Epoch 16/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9353 - loss: 1.0869 - val_accuracy: 0.9000 - val_loss: 1.1060
# Epoch 17/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9264 - loss: 1.0469 - val_accuracy: 0.8886 - val_loss: 1.0804
# Epoch 18/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9390 - loss: 1.0183 - val_accuracy: 0.8932 - val_loss: 1.0525
# Epoch 19/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9377 - loss: 1.0033 - val_accuracy: 0.9045 - val_loss: 1.0249
# Epoch 20/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9427 - loss: 0.9883 - val_accuracy: 0.9136 - val_loss: 1.0040
# Epoch 21/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9399 - loss: 0.9526 - val_accuracy: 0.9159 - val_loss: 0.9761
# Epoch 22/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9518 - loss: 0.9239 - val_accuracy: 0.9114 - val_loss: 0.9663
# Epoch 23/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9449 - loss: 0.9101 - val_accuracy: 0.9091 - val_loss: 0.9364
# Epoch 24/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9464 - loss: 0.8858 - val_accuracy: 0.9205 - val_loss: 0.9142
# Epoch 25/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9484 - loss: 0.8817 - val_accuracy: 0.9273 - val_loss: 0.9028
# Epoch 26/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9540 - loss: 0.8527 - val_accuracy: 0.9182 - val_loss: 0.8833
# Epoch 27/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9471 - loss: 0.8364 - val_accuracy: 0.9273 - val_loss: 0.8687
# Epoch 28/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9531 - loss: 0.8117 - val_accuracy: 0.9273 - val_loss: 0.8450
# Epoch 29/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9498 - loss: 0.8099 - val_accuracy: 0.9295 - val_loss: 0.8361
# Epoch 30/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9596 - loss: 0.7719 - val_accuracy: 0.9364 - val_loss: 0.8148
# Epoch 31/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9655 - loss: 0.7625 - val_accuracy: 0.9273 - val_loss: 0.8080
# Epoch 32/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9594 - loss: 0.7527 - val_accuracy: 0.9273 - val_loss: 0.7926
# Epoch 33/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9687 - loss: 0.7324 - val_accuracy: 0.9341 - val_loss: 0.7796
# Epoch 34/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9617 - loss: 0.7207 - val_accuracy: 0.9295 - val_loss: 0.7631
# Epoch 35/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9646 - loss: 0.7105 - val_accuracy: 0.9273 - val_loss: 0.7545
# Epoch 36/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9637 - loss: 0.6929 - val_accuracy: 0.9295 - val_loss: 0.7455
# Epoch 37/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9682 - loss: 0.6906 - val_accuracy: 0.9409 - val_loss: 0.7301
# Epoch 38/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9655 - loss: 0.6837 - val_accuracy: 0.9386 - val_loss: 0.7198
# Epoch 39/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9632 - loss: 0.6774 - val_accuracy: 0.9409 - val_loss: 0.7112
# Epoch 40/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9637 - loss: 0.6467 - val_accuracy: 0.9409 - val_loss: 0.7036
# Epoch 41/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9688 - loss: 0.6425 - val_accuracy: 0.9432 - val_loss: 0.6933
# Epoch 42/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9650 - loss: 0.6305 - val_accuracy: 0.9318 - val_loss: 0.6841
# Epoch 43/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9651 - loss: 0.6233 - val_accuracy: 0.9455 - val_loss: 0.6752
# Epoch 44/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9748 - loss: 0.6220 - val_accuracy: 0.9432 - val_loss: 0.6667
# Epoch 45/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9655 - loss: 0.6072 - val_accuracy: 0.9432 - val_loss: 0.6558
# Epoch 46/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9663 - loss: 0.6029 - val_accuracy: 0.9386 - val_loss: 0.6520
# Epoch 47/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9662 - loss: 0.5965 - val_accuracy: 0.9500 - val_loss: 0.6422
# Epoch 48/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9704 - loss: 0.5939 - val_accuracy: 0.9455 - val_loss: 0.6360
# Epoch 49/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9667 - loss: 0.5926 - val_accuracy: 0.9409 - val_loss: 0.6233
# Epoch 50/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9717 - loss: 0.5698 - val_accuracy: 0.9500 - val_loss: 0.6192
# Epoch 51/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9693 - loss: 0.5704 - val_accuracy: 0.9432 - val_loss: 0.6132
# Epoch 52/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9675 - loss: 0.5645 - val_accuracy: 0.9500 - val_loss: 0.6068
# Epoch 53/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9704 - loss: 0.5631 - val_accuracy: 0.9455 - val_loss: 0.5995
# Epoch 54/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9738 - loss: 0.5489 - val_accuracy: 0.9432 - val_loss: 0.5968
# Epoch 55/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9682 - loss: 0.5465 - val_accuracy: 0.9477 - val_loss: 0.5879
# Epoch 56/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9767 - loss: 0.5327 - val_accuracy: 0.9477 - val_loss: 0.5777
# Epoch 57/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9743 - loss: 0.5301 - val_accuracy: 0.9477 - val_loss: 0.5786
# Epoch 58/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9767 - loss: 0.5275 - val_accuracy: 0.9432 - val_loss: 0.5707
# Epoch 59/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9662 - loss: 0.5228 - val_accuracy: 0.9545 - val_loss: 0.5622
# Epoch 60/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9726 - loss: 0.5012 - val_accuracy: 0.9500 - val_loss: 0.5592
# Epoch 61/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9699 - loss: 0.5079 - val_accuracy: 0.9500 - val_loss: 0.5549
# Epoch 62/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9661 - loss: 0.5017 - val_accuracy: 0.9500 - val_loss: 0.5507
# Epoch 63/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9701 - loss: 0.4983 - val_accuracy: 0.9432 - val_loss: 0.5447
# Epoch 64/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9662 - loss: 0.4970 - val_accuracy: 0.9455 - val_loss: 0.5370
# Epoch 65/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9719 - loss: 0.4888 - val_accuracy: 0.9477 - val_loss: 0.5349
# Epoch 66/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9730 - loss: 0.4740 - val_accuracy: 0.9477 - val_loss: 0.5294
# Epoch 67/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9755 - loss: 0.4641 - val_accuracy: 0.9523 - val_loss: 0.5263
# Epoch 68/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9720 - loss: 0.4761 - val_accuracy: 0.9523 - val_loss: 0.5182
# Epoch 69/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9729 - loss: 0.4610 - val_accuracy: 0.9568 - val_loss: 0.5178
# Epoch 70/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9752 - loss: 0.4598 - val_accuracy: 0.9545 - val_loss: 0.5118
# Epoch 71/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9740 - loss: 0.4576 - val_accuracy: 0.9523 - val_loss: 0.5053
# Epoch 72/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9726 - loss: 0.4625 - val_accuracy: 0.9614 - val_loss: 0.4962
# Epoch 73/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9723 - loss: 0.4580 - val_accuracy: 0.9545 - val_loss: 0.4975
# Epoch 74/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9764 - loss: 0.4463 - val_accuracy: 0.9591 - val_loss: 0.4923
# Epoch 75/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9759 - loss: 0.4385 - val_accuracy: 0.9568 - val_loss: 0.4902
# Epoch 76/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9740 - loss: 0.4401 - val_accuracy: 0.9591 - val_loss: 0.4844
# Epoch 77/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9710 - loss: 0.4518 - val_accuracy: 0.9545 - val_loss: 0.4856
# Epoch 78/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9701 - loss: 0.4357 - val_accuracy: 0.9614 - val_loss: 0.4795
# Epoch 79/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9778 - loss: 0.4267 - val_accuracy: 0.9636 - val_loss: 0.4742
# Epoch 80/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9830 - loss: 0.4227 - val_accuracy: 0.9659 - val_loss: 0.4755
# Epoch 81/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9732 - loss: 0.4220 - val_accuracy: 0.9568 - val_loss: 0.4703
# Epoch 82/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9733 - loss: 0.4250 - val_accuracy: 0.9614 - val_loss: 0.4646
# Epoch 83/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9710 - loss: 0.4220 - val_accuracy: 0.9636 - val_loss: 0.4635
# Epoch 84/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9754 - loss: 0.4159 - val_accuracy: 0.9614 - val_loss: 0.4579
# Epoch 85/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9784 - loss: 0.4109 - val_accuracy: 0.9591 - val_loss: 0.4521
# Epoch 86/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9687 - loss: 0.4124 - val_accuracy: 0.9636 - val_loss: 0.4534
# Epoch 87/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9726 - loss: 0.4066 - val_accuracy: 0.9614 - val_loss: 0.4547
# Epoch 88/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9748 - loss: 0.3983 - val_accuracy: 0.9545 - val_loss: 0.4493
# Epoch 89/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9752 - loss: 0.3973 - val_accuracy: 0.9682 - val_loss: 0.4385
# Epoch 90/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9813 - loss: 0.3825 - val_accuracy: 0.9614 - val_loss: 0.4378
# Epoch 91/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9740 - loss: 0.3988 - val_accuracy: 0.9614 - val_loss: 0.4402
# Epoch 92/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9808 - loss: 0.3815 - val_accuracy: 0.9659 - val_loss: 0.4323
# Epoch 93/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9732 - loss: 0.3957 - val_accuracy: 0.9659 - val_loss: 0.4302
# Epoch 94/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9815 - loss: 0.3843 - val_accuracy: 0.9568 - val_loss: 0.4340
# Epoch 95/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9713 - loss: 0.3931 - val_accuracy: 0.9614 - val_loss: 0.4284
# Epoch 96/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9801 - loss: 0.3847 - val_accuracy: 0.9545 - val_loss: 0.4289
# Epoch 97/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9821 - loss: 0.3642 - val_accuracy: 0.9591 - val_loss: 0.4175
# Epoch 98/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9796 - loss: 0.3765 - val_accuracy: 0.9614 - val_loss: 0.4164
# Epoch 99/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9731 - loss: 0.3790 - val_accuracy: 0.9636 - val_loss: 0.4155
# Epoch 100/100
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9792 - loss: 0.3665 - val_accuracy: 0.9659 - val_loss: 0.4111
# Restoring model weights from the end of the best epoch: 100.

# %%
print("TRAINING ACCURACY: ",model.evaluate(xtrain,ytrain)[1]*100)
print("TESTING ACCURACY: ",model.evaluate(xtest,ytest)[1]*100)
# Out:
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9757 - loss: 0.3644
# TRAINING ACCURACY:  98.1249988079071
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9692 - loss: 0.4197
# TESTING ACCURACY:  96.59090638160706

# %%
plt.figure(figsize=(12,6))
plt.suptitle("Feedforward Neural Network Model",fontsize=16)
plt.subplot(1,2,1)
plt.plot(model_history.history['accuracy'],color='Black')
plt.plot(model_history.history['val_accuracy'],color='Red')
plt.xlabel("EPOCHS")
plt.ylabel("ACCURACY LEVEL")
plt.grid()
plt.legend(['train','test'])
plt.subplot(1,2,2)
plt.plot(model_history.history['loss'],color='Black')
plt.plot(model_history.history['val_loss'],color='Red')
plt.xlabel("EPOCHS")
plt.ylabel("LOSS LEVEL")
plt.grid()
plt.legend(['train','test'])
plt.show()

# %%
ypr=model.predict(xtest)
ypred=np.argmax(ypr,axis=1)
ypred
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# array([15, 21, 17, 17,  0, 12,  0, 13, 14, 10,  2,  4, 19,  8,  4, 19,  0,
#        11, 17, 15,  5, 17, 16, 17,  3,  8, 14, 16, 18, 20, 19, 10,  8, 10,
#         8,  2,  8,  3,  3,  9, 17, 12,  2, 11, 14, 11, 18,  4, 15, 11,  2,
#         5,  7, 14,  5,  9,  6,  0,  1, 10, 21,  4, 10, 16, 17, 18, 16, 20,
#        15, 18, 15,  4,  8,  1,  2, 17,  1,  6, 21, 16,  5,  3,  8, 13, 16,
#        12,  5, 13,  2, 19, 11, 13,  6, 17, 18, 13,  9,  5,  2, 10,  4,  8,
#        16, 15, 21,  9, 21,  1, 18, 13,  1,  8,  6, 19, 18,  3, 11,  4, 19,
#        20, 18,  7,  2,  4,  3,  2,  4, 11,  1, 13,  1,  9, 19,  3,  4, 16,
#        18,  1,  1,  0,  9, 15, 14, 13,  4,  6,  0,  4,  9, 13, 14, 10, 21,
#        14, 18, 18, 18,  9, 11,  8,  3,  0, 16,  6, 20,  4,  7, 10, 21,  7,
#         7,  2, 19,  3,  4, 11, 10,  7, 21,  8,  5,  5,  9,  8, 13,  9,  1,
#         9,  4, 17, 17, 14, 12, 19, 21,  9, 11,  0,  2,  3,  7,  7,  1,  6,
#        20, 19, 14,  1,  8, 14, 11,  3,  3,  3,  0, 20,  9, 17,  5,  2,  9,
#        12, 12,  4, 17,  0,  3, 19,  3, 15,  0, 15, 15, 12, 12,  6,  4, 19,
#        20, 15,  5, 17, 10, 11, 12, 15,  2, 14,  5,  7,  4,  6, 18, 20,  0,
#        19,  5,  3,  6,  8, 12,  1, 17,  0,  3, 20, 18, 13, 14,  8, 19,  7,
#        13,  8, 11,  4, 11,  3,  1,  8,  4,  5, 12, 15,  0,  1, 18,  2, 16,
#         3, 21,  1,  0,  3,  5, 18, 16,  0,  4, 17, 21, 12, 17,  3, 19,  3,
#        17, 10,  0, 19,  3, 12,  3, 19, 21,  9, 14, 15, 21,  9, 15, 12,  8,
#         2,  3,  1,  2, 18, 17,  9, 14,  4,  6,  7,  0, 10,  1,  8,  0, 19,
#         0, 14, 15,  5,  5, 18,  8,  9,  1, 11,  8, 11, 18, 12,  9, 19, 21,
#         2, 11, 20, 13,  9, 12,  6, 17, 13,  6, 14, 16, 20,  2, 14,  5,  1,
#        18, 17,  0, 19, 11, 12,  4,  0, 10,  8, 13, 10,  4,  2,  8, 14,  6,
#        21,  0,  7,  4,  7, 21, 20, 12, 12,  5, 19,  1,  7,  8, 16,  6, 12,
#        17, 15, 13,  8,  3, 13, 19, 21, 13,  6, 17, 21, 10, 20,  4, 13, 13,
#        11, 20, 11,  4, 16, 19,  9, 21, 14,  2, 20, 20,  6,  6,  9])

# %%
data=pd.read_csv(r"C:\Users\Avijit\Desktop\AgriAssure\CROP_RECOMMENDATION\DATASET\Crop_recommendation.csv")

# %%
cm=confusion_matrix(ytest,ypred)
class_name=data['label'].unique().tolist()
plt.figure(figsize=(33,22))
sns.heatmap(cm,fmt='d',cmap='Greens',annot=True,xticklabels=class_name,yticklabels=class_name,linecolor="black",linewidths=0.7)
plt.xlabel('[ Predicited ] ',fontsize=24,labelpad=20)
plt.ylabel('[ Actual ] ',fontsize=24,labelpad=20)
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
metrics=['Accuracy',"Precision","Recall",'F1 score']
scores=[accuracy_score(ytest,ypred)*100,precision_score(ytest,ypred,average='macro')*100,recall_score(ytest,ypred,average='macro')*100,f1_score(ytest,ypred,average='macro')*100]
plt.bar(metrics,scores,color=['green','red','blue','purple'])
plt.title("classification metrics for crop recommendation system")
plt.xlabel("METRICS")
plt.yticks(range(0,101,5))
plt.show()

# %%
joblib.dump(model,r"C:\Users\Avijit\Desktop\AgriAssure\CROP_RECOMMENDATION\MODELS\fnn.pkl")
# Out:
# ['C:\\Users\\Avijit\\Desktop\\AgriAssure\\CROP_RECOMMENDATION\\MODELS\\fnn.pkl']
